# %% [markdown]
# # Conecta drive

# %% [markdown]
# # Nova seção

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #instalações

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics 
import pandas as pd
from pandas.core import algorithms
import numpy as np
# !pip install deap
import random
from sklearn.preprocessing import LabelEncoder
from deap import creator, base, tools, algorithms
import sys
import time 
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier 
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
import pandas as pd
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import CategoricalNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot
import random
import statistics
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import MinMaxScaler
from sklearn import svm

# %%
inicio = time.time()
print("Gerações Genético")
#importa dados
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

print(X)
#Separa atributos
X = df.iloc[:, :-1]
X = pd.get_dummies(X) 
print(X.columns)
X.count(axis=0)
print(X)
# Out:
# Gerações Genético
#      raisedhands  ...  StudentAbsenceDays_Under-7
# 0             15  ...                           1
# 1             20  ...                           1
# 2             10  ...                           0
# 3             30  ...                           0
# 4             40  ...                           0
# ..           ...  ...                         ...
# 474            5  ...                           0
# 475           50  ...                           1
# 476           55  ...                           1
# 477           30  ...                           0
# 478           35  ...                           0
#
# [479 rows x 70 columns]
# Index(['raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'gender_F', 'gender_M', 'NationalITy_Egypt', 'NationalITy_Iran',
#        'NationalITy_Iraq', 'NationalITy_Jordan', 'NationalITy_KW',
#        'NationalITy_Lybia', 'NationalITy_Morocco', 'NationalITy_Palestine',
# ...

# %% [markdown]
# # Random Forest

# %%
RelatorioRF =[]
Relatorio_f1RF=[]
qtdatribRF=[]

# %%
while (len(Relatorio_f1RF)<11):
 inicio = time.time()
 print("Gerações Genético")
 #importa dados
 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

 #Separa atributos
 X = df.iloc[:, :-1]
 X = pd.get_dummies(X) 
 #Normalização  dos dados 
 X_minMax = X.copy()
 X_minMax[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']] = MinMaxScaler().fit_transform(X[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']])
 X = X_minMax

 #Codifica alvo
 le = LabelEncoder()
 le.fit(df.iloc[:, -1])
 y = le.transform(df.iloc[:, -1])  #apenas a ultima coluna codificada

 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

 inicio = time.time()

#-----# validação cruzada 5 kfold na base de treino #---#
 Acurácia = []
 reportf1 =[]
 reportprecision =[]
 reportrecall=[]
 modelolist=[]

 modelo=RandomForestClassifier(random_state=0, n_estimators = 1000)
 modelo =modelo.fit(X_train, y_train)
 p= modelo.predict(X_test)
 acc = accuracy_score(y_test, p)
 f1= f1_score(y_test,p,average='macro')
 fim = time.time()
 print("tempo AM",fim - inicio)

 RelatorioRF.append(acc)
 Relatorio_f1RF.append(f1)
 print("Resultado experimentos")
 print("quantidade experimentos",len(RelatorioRF))
 Tab_rel = pd.DataFrame(RelatorioRF)  
 Tab_rel_f1 = pd.DataFrame(Relatorio_f1RF)
 print('f1_tabela',Tab_rel_f1)
 print("Acuracia média",Tab_rel.mean(axis=0))
 print("f1 médio",Tab_rel_f1.mean(axis=0))
 print("desvio f1",Tab_rel_f1.std(axis=0))
# Out:
# Gerações Genético
# tempo AM 1.828587293624878
# Resultado experimentos
# quantidade experimentos 1
# f1_tabela          0
# 0  0.75962
# Acuracia média 0    0.75
# dtype: float64
# f1 médio 0    0.75962
# dtype: float64
# desvio f1 0   NaN
# dtype: float64
# Gerações Genético
# tempo AM 1.7402927875518799
# Resultado experimentos
# quantidade experimentos 2
# f1_tabela          0
# 0  0.75962
# 1  0.78712
# Acuracia média 0    0.767361
# dtype: float64
# f1 médio 0    0.77337
# dtype: float64
# desvio f1 0    0.019445
# dtype: float64
# Gerações Genético
# tempo AM 1.7397501468658447
# Resultado experimentos
# quantidade experimentos 3
# f1_tabela           0
# 0  0.759620
# 1  0.787120
# 2  0.811668
# Acuracia média 0    0.782407
# dtype: float64
# f1 médio 0    0.786136
# dtype: float64
# desvio f1 0    0.026038
# dtype: float64
# Gerações Genético
# tempo AM 1.7002296447753906
# Resultado experimentos
# quantidade experimentos 4
# f1_tabela           0
# 0  0.759620
# ...

# %% [markdown]
# #KNN

# %%
RelatorioKNN =[]
Relatorio_f1KNN=[]
qtdatribKNN=[]

# %%
while (len(Relatorio_f1KNN)<11):
 inicio = time.time()
 print("Gerações Genético")
#importa dados
 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

#Separa atributos
 X = df.iloc[:, :-1]
 X = pd.get_dummies(X) 
 #Normalização  dos dados 
 X_minMax = X.copy()
 X_minMax[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']] = MinMaxScaler().fit_transform(X[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']])
 X = X_minMax


#Codifica alvo
 le = LabelEncoder()
 le.fit(df.iloc[:, -1])
 y = le.transform(df.iloc[:, -1])  #apenas a ultima coluna codificada

 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)




#-----# validação cruzada 5 kfold na base de treino #---#
 inicio = time.time()
 Acurácia = []
 reportf1 =[]
 reportprecision =[]
 reportrecall=[]
 modelolist=[]
 

 modelo = KNeighborsClassifier(n_neighbors=5, p=2,weights='distance')
 modelo =modelo.fit(X_train, y_train)
 p= modelo.predict(X_test)
 acc = accuracy_score(y_test, p)
 f1= f1_score(y_test, p,average='macro')
 fim = time.time()
 print("tempo AM",fim - inicio)

 RelatorioKNN.append(acc)
 Relatorio_f1KNN.append(f1)
 print("Resultado experimentos")
 print("quantidade experimentos",len(RelatorioKNN))
 Tab_rel = pd.DataFrame(RelatorioKNN)  
 Tab_rel_f1 = pd.DataFrame(Relatorio_f1KNN)
 print('f1_tabela',Tab_rel_f1)
 print("Acuracia média",Tab_rel.mean(axis=0))
 print("f1 médio",Tab_rel_f1.mean(axis=0)) # 0 indica 10 atributos e 6 indica 70 atributos
 print("desvio f1",Tab_rel_f1.std(axis=0))
# Out:
# Gerações Genético
# tempo AM 0.011466741561889648
# Resultado experimentos
# quantidade experimentos 1
# f1_tabela           0
# 0  0.699836
# Acuracia média 0    0.694444
# dtype: float64
# f1 médio 0    0.699836
# dtype: float64
# desvio f1 0   NaN
# dtype: float64
# Gerações Genético
# tempo AM 0.01100301742553711
# Resultado experimentos
# quantidade experimentos 2
# f1_tabela           0
# 0  0.699836
# 1  0.662307
# Acuracia média 0    0.677083
# dtype: float64
# f1 médio 0    0.681071
# dtype: float64
# desvio f1 0    0.026537
# dtype: float64
# Gerações Genético
# tempo AM 0.011000394821166992
# Resultado experimentos
# quantidade experimentos 3
# f1_tabela           0
# 0  0.699836
# 1  0.662307
# 2  0.684623
# Acuracia média 0    0.678241
# dtype: float64
# f1 médio 0    0.682255
# dtype: float64
# desvio f1 0    0.018876
# dtype: float64
# Gerações Genético
# tempo AM 0.011038541793823242
# Resultado experimentos
# quantidade experimentos 4
# f1_tabela           0
# ...

# %% [markdown]
# #Naive Bayes

# %%
RelatorioNB =[]
Relatorio_f1NB=[]
qtdatribNB=[]

# %%
while (len(Relatorio_f1NB)<11):
 inicio = time.time()
 print("Gerações Genético")
#importa dados
 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

#Separa atributos
 X = df.iloc[:, :-1]
 X = pd.get_dummies(X) 
 #Normalização  dos dados 
 X_minMax = X.copy()
 X_minMax[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']] = MinMaxScaler().fit_transform(X[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']])
 X = X_minMax

#Codifica alvo
 le = LabelEncoder()
 le.fit(df.iloc[:, -1])
 y = le.transform(df.iloc[:, -1])  #apenas a ultima coluna codificada

 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)




#-----# validação cruzada 5 kfold na base de treino #---#
 inicio = time.time()
 Acurácia = []
 reportf1 =[]
 reportprecision =[]
 reportrecall=[]
 modelolist=[]
 modelo =  GaussianNB(var_smoothing=0.01)
 modelo =modelo.fit(X_train, y_train)
 p= modelo.predict(X_test)
 acc = accuracy_score(y_test, p)
  
     
 f1= f1_score(y_test, p,average='macro')
 fim = time.time()
 print("tempo AM",fim - inicio)

 RelatorioNB.append(acc)
 Relatorio_f1NB.append(f1)
 print("Resultado experimentos")
 print("quantidade experimentos",len(RelatorioNB))
 Tab_rel = pd.DataFrame(RelatorioNB)  
 Tab_rel_f1 = pd.DataFrame(Relatorio_f1NB)
 print('f1_tabela',Tab_rel_f1)
 print("desvio f1",Tab_rel_f1.std(axis=0))
 print("Acuracia média",Tab_rel.mean(axis=0))

 print("f1 médio",Tab_rel_f1.mean(axis=0)) 
 print("desvio f1",Tab_rel_f1.std(axis=0))
# Out:
# Gerações Genético
# tempo AM 0.0034668445587158203
# Resultado experimentos
# quantidade experimentos 1
# f1_tabela           0
# 0  0.683557
# desvio f1 0   NaN
# dtype: float64
# Acuracia média 0    0.673611
# dtype: float64
# f1 médio 0    0.683557
# dtype: float64
# desvio f1 0   NaN
# dtype: float64
# Gerações Genético
# tempo AM 0.0036191940307617188
# Resultado experimentos
# quantidade experimentos 2
# f1_tabela           0
# 0  0.683557
# 1  0.667345
# desvio f1 0    0.011463
# dtype: float64
# Acuracia média 0    0.670139
# dtype: float64
# f1 médio 0    0.675451
# dtype: float64
# desvio f1 0    0.011463
# dtype: float64
# Gerações Genético
# tempo AM 0.0033559799194335938
# Resultado experimentos
# quantidade experimentos 3
# f1_tabela           0
# 0  0.683557
# 1  0.667345
# 2  0.673193
# desvio f1 0    0.00821
# dtype: float64
# Acuracia média 0    0.668981
# dtype: float64
# f1 médio 0    0.674698
# dtype: float64
# desvio f1 0    0.00821
# dtype: float64
# ...

# %% [markdown]
# #Rede Neural

# %%
RelatorioRN =[]
Relatorio_f1RN=[]
qtdatribRN=[]

# %%
while (len(Relatorio_f1RN)<11):
 inicio = time.time()
 print("Gerações Genético")
#importa dados
 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

#Separa atributos
 X = df.iloc[:, :-1]
 X = pd.get_dummies(X)
 #Normalização  dos dados 
 X_minMax = X.copy()
 X_minMax[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']] = MinMaxScaler().fit_transform(X[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']])
 X = X_minMax 


#Codifica alvo
 le = LabelEncoder()
 le.fit(df.iloc[:, -1])
 y = le.transform(df.iloc[:, -1])  #apenas a ultima coluna codificada

 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)







#-----# validação cruzada 10 kfold na base de treino #---#
 inicio = time.time()
 Acurácia = []
 reportf1 =[]
 reportprecision =[]
 reportrecall=[]
 modelolist=[]
 modelo = MLPClassifier(random_state=1, max_iter=300)
 modelo =modelo.fit(X_train, y_train)
 p= modelo.predict(X_test)
 acc = accuracy_score(y_test, p)

 f1= f1_score(y_test, p,average='macro')
 fim = time.time()
 print("tempo",fim - inicio)

 RelatorioRN.append(acc)
 Relatorio_f1RN.append(f1)
 print("Resultado experimentos")
 print("quantidade experimentos",len(RelatorioRN))
 Tab_rel = pd.DataFrame(RelatorioRN)  
 Tab_rel_f1 = pd.DataFrame(Relatorio_f1RN)
 print('f1_tabela',Tab_rel_f1)

 print("Acuracia média",Tab_rel.mean(axis=0))
 print("f1 médio",Tab_rel_f1.mean(axis=0))
 print("desvio f1",Tab_rel_f1.std(axis=0))
# Out:
# Gerações Genético
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# tempo 0.9384479522705078
# Resultado experimentos
# quantidade experimentos 1
# f1_tabela          0
# 0  0.66466
# Acuracia média 0    0.659722
# dtype: float64
# f1 médio 0    0.66466
# dtype: float64
# desvio f1 0   NaN
# dtype: float64
# Gerações Genético
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# tempo 0.9036924839019775
# Resultado experimentos
# quantidade experimentos 2
# f1_tabela          0
# 0  0.66466
# 1  0.74221
# Acuracia média 0    0.697917
# dtype: float64
# f1 médio 0    0.703435
# ...

# %% [markdown]
# #SVM

# %%
RelatorioSVM =[]
Relatorio_f1SVM=[]
qtdatribSVM=[]

# %%
while (len(Relatorio_f1SVM)<11):
 inicio = time.time()
 print("Gerações Genético")
#importa dados
 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data.csv')

#Separa atributos
 X = df.iloc[:, :-1]
 X = pd.get_dummies(X)
 #Normalização  dos dados 
 X_minMax = X.copy()
 X_minMax[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']] = MinMaxScaler().fit_transform(X[['raisedhands', 'VisITedResources', 'AnnouncementsView','Discussion']])
 X = X_minMax 


#Codifica alvo
 le = LabelEncoder()
 le.fit(df.iloc[:, -1])
 y = le.transform(df.iloc[:, -1])  #apenas a ultima coluna codificada

 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)







#-----# validação cruzada 10 kfold na base de treino #---#
 inicio = time.time()
 Acurácia = []
 reportf1 =[]
 reportprecision =[]
 reportrecall=[]
 modelolist=[]
 modelo = svm.SVC(kernel='linear')
 modelo =modelo.fit(X_train, y_train)
 p= modelo.predict(X_test)
 acc = accuracy_score(y_test, p)

 f1= f1_score(y_test, p,average='macro')
 fim = time.time()
 print("tempo",fim - inicio)

 RelatorioSVM.append(acc)
 Relatorio_f1SVM.append(f1)
 print("Resultado experimentos")
 print("quantidade experimentos",len(RelatorioSVM))
 Tab_rel = pd.DataFrame(RelatorioSVM)  
 Tab_rel_f1 = pd.DataFrame(Relatorio_f1SVM)
 print('f1_tabela',Tab_rel_f1)

 print("Acuracia média",Tab_rel.mean(axis=0))
 print("f1 médio",Tab_rel_f1.mean(axis=0))
 print("desvio f1",Tab_rel_f1.std(axis=0))
# Out:
# Gerações Genético
# tempo 0.015260457992553711
# Resultado experimentos
# quantidade experimentos 1
# f1_tabela           0
# 0  0.795271
# Acuracia média 0    0.791667
# dtype: float64
# f1 médio 0    0.795271
# dtype: float64
# desvio f1 0   NaN
# dtype: float64
# Gerações Genético
# tempo 0.014839649200439453
# Resultado experimentos
# quantidade experimentos 2
# f1_tabela           0
# 0  0.795271
# 1  0.804300
# Acuracia média 0    0.795139
# dtype: float64
# f1 médio 0    0.799786
# dtype: float64
# desvio f1 0    0.006385
# dtype: float64
# Gerações Genético
# tempo 0.012827873229980469
# Resultado experimentos
# quantidade experimentos 3
# f1_tabela           0
# 0  0.795271
# 1  0.804300
# 2  0.722211
# Acuracia média 0    0.768519
# dtype: float64
# f1 médio 0    0.773927
# dtype: float64
# desvio f1 0    0.045015
# dtype: float64
# Gerações Genético
# tempo 0.017899036407470703
# Resultado experimentos
# quantidade experimentos 4
# f1_tabela           0
# 0  0.795271
# ...
